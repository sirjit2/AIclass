# %%
#Task1
import numpy as np

a1 = np.empty((2,2))
a2 = np.ones((4,2))
a3 = np.full((3,3), 7)
arr = np.array([[1,2,3],[4,5,6]])
a4 = np.zeros_like(arr)
a5 = np.ones_like(arr)
new_list = [1,2,3,4]
a6 = np.array(new_list)

# %%
#Task2
import numpy as np

p1 = np.arange(10,50)
p2 = np.arange(9).reshape(3,3)
p3 = np.eye(3)
p4 = np.random.random(30).mean()
arr10 = np.random.random((10,10))
p5_min, p5_max = arr10.min(), arr10.max()
p6 = np.zeros(10); p6[4] = 1
arr_rev = np.array([1,2,0,0,4,0])[::-1]
p8 = np.ones((5,5)); p8[1:-1,1:-1] = 0
p9 = np.zeros((8,8)); p9[::2,1::2] = 1; p9[1::2,::2] = 1

# %%
#Task4
import numpy as np

A = np.array([[3,4],[7,8]])
B = np.array([[5,3],[2,1]])

invA = np.linalg.inv(A)
proof1 = A.dot(invA)

proof2_AB = A.dot(B)
proof2_BA = B.dot(A)

proof3 = (A.dot(B)).T
proof3_check = B.T.dot(A.T)

C = np.array([[2,-3,1],[1,-1,2],[3,1,-1]])
D = np.array([-1,-3,9])

X = np.linalg.solve(C,D)

X_inv = np.linalg.inv(C).dot(D)

# %%
#Task3
import numpy as np

x = np.array([[1,2],[3,5]])
y = np.array([[5,6],[7,8]])
v = np.array([9,10])
w = np.array([11,12])

t1 = x + y
t2 = x - y
t3 = x * 3
t4 = x**2
dot_vw = np.dot(v,w)
dot_xv = np.dot(x,v)
dot_xy = np.dot(x,y)
cat_xy = np.concatenate((x,y), axis=0)
cat_vw = np.vstack((v,w))
# concatenating x and v causes shape mismatch

# %%
#Task5
import numpy as np
import time

size = 1_000_000

L1 = list(range(size))
L2 = list(range(size))
start = time.time()
L_add = [L1[i] + L2[i] for i in range(size)]
t_list_add = time.time() - start

A1 = np.arange(size)
A2 = np.arange(size)
start = time.time()
A_add = A1 + A2
t_np_add = time.time() - start

start = time.time()
L_mul = [L1[i] * L2[i] for i in range(size)]
t_list_mul = time.time() - start

start = time.time()
A_mul = A1 * A2
t_np_mul = time.time() - start

start = time.time()
dot_list = sum(L1[i] * L2[i] for i in range(size))
t_list_dot = time.time() - start

start = time.time()
dot_np = np.dot(A1, A2)
t_np_dot = time.time() - start

M1 = np.random.random((1000,1000)).tolist()
M2 = np.random.random((1000,1000)).tolist()
start = time.time()
result_list = [[sum(a*b for a,b in zip(r,c)) for c in zip(*M2)] for r in M1]
t_list_matmul = time.time() - start

M1_np = np.random.random((1000,1000))
M2_np = np.random.random((1000,1000))
start = time.time()
result_np = M1_np.dot(M2_np)
t_np_matmul = time.time() - start

# %%
import numpy as np
